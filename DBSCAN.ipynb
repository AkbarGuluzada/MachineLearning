# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
blobs = pd.read_csv("C:\\Users\\User\\Downloads\\UNZIP_FOR_NOTEBOOKS_FINAL (1)\\DATA\\cluster_blobs.csv")
moons = pd.read_csv("C:\\Users\\User\\Downloads\\UNZIP_FOR_NOTEBOOKS_FINAL (1)\\DATA\\cluster_moons.csv")
circles = pd.read_csv("C:\\Users\\User\\Downloads\\UNZIP_FOR_NOTEBOOKS_FINAL (1)\\DATA\\cluster_circles.csv")

# %%
def model_display(model,data):
    labels = model.fit_predict(data)
    plt.figure(figsize = (12,8), dpi = 300)
    sns.scatterplot(data = data, x='X1', y = 'X2',hue = labels)
    plt.show()

# %%
from sklearn.cluster import KMeans

# %%
from sklearn.cluster import DBSCAN

# %%
model1 = KMeans(n_clusters=2)
model2 = DBSCAN(eps=0.15)

# %%
model_display(model1,blobs)
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=6.
#   warnings.warn(

# %%
model_display(model2,blobs)

# %%
model_display(model1,circles)
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=6.
#   warnings.warn(

# %%
two_blobs = pd.read_csv("C:\\Users\\User\\Downloads\\UNZIP_FOR_NOTEBOOKS_FINAL (1)\\DATA\\cluster_two_blobs.csv")

# %%
two_blobs_outliers = pd.read_csv("C:\\Users\\User\\Downloads\\UNZIP_FOR_NOTEBOOKS_FINAL (1)\\DATA\\cluster_two_blobs_outliers.csv")

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def model_display(model, data):
    cluster_labels = model.fit_predict(data)
    plt.figure(figsize=(2, 2), dpi=300)
    sns.scatterplot(data=data, x='X1', y='X2', hue=cluster_labels, s=10)  # s is the marker size
    plt.legend(fontsize=4, title='Cluster', title_fontsize=5)  # control legend size
    plt.tight_layout()
    plt.show()

# %%
from sklearn.cluster import DBSCAN

# %%
model = DBSCAN()

# %%
model_display(model,two_blobs)

# %%
model_display(model,two_blobs_outliers)

# %%
outliers_in_nums = []
outliers_as_perc = []
for eps in np.linspace(0.001,7,200):
    model = DBSCAN(eps = eps)
    model.fit(two_blobs_outliers)
    outliers_in_nums.append(np.sum(model.labels_ == -1))
    outliers_as_perc.append((np.sum(model.labels_ == -1)*100/len(labels)))

# %%
sns.lineplot(y=outliers_in_nums,x=np.linspace(0.001,7,200))
plt.xlim(0,2)
plt.ylim(0,10)
plt.hlines(y=3,xmin=0,xmax=2,color='red')
plt.show()

# %%
model = DBSCAN(eps=7)

# %%
model_display(model,two_blobs_outliers)

# %%
sns.lineplot(y=outliers_as_perc,x=np.linspace(0.001,7,200))
plt.xlim(0,2)
plt.ylim(0,10)
plt.hlines(y=1,xmin=0,xmax=2,color='red')
plt.show()

# %%
outliers_in_nums = []
outliers_as_perc = []
for n in np.arange(1,100):
    model = DBSCAN(min_samples= n)
    model.fit(two_blobs_outliers)
    outliers_in_nums.append(np.sum(model.labels_ == -1))
    outliers_as_perc.append((np.sum(model.labels_ == -1)*100/len(labels)))

# %%
sns.lineplot(y=outliers_as_perc,x=np.arange(1,100))
plt.show()

# %%
model = DBSCAN(min_samples=2*two_blobs_outliers.shape[1],eps=0.75)

# %%
model_display(model,two_blobs_outliers)
