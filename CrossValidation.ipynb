# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("C:\\Users\\User\\Downloads\\UNZIP_FOR_NOTEBOOKS_FINAL (1)\\DATA\\Advertising.csv")

# %%
df
# Out:
#         TV  radio  newspaper  sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
from sklearn.preprocessing import StandardScaler

# %%
X = df.drop('sales',axis = 1)
y = df['sales']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=101)

# %%
scaler = StandardScaler()

# %%
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
scaled_X_train = scaler.transform(X_train)

# %%
scaled_X_test = scaler.transform(X_test)

# %%
from sklearn.linear_model import Ridge

# %%
model = Ridge(alpha = 100)

# %%
model.fit(scaled_X_train,y_train)
# Out:
# Ridge(alpha=100)

# %%
y_pred = model.predict(scaled_X_test)

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 7.341775789034129

# %%
model_two = Ridge(alpha = 1)

# %%
model_two.fit(scaled_X_train,y_train)
# Out:
# Ridge(alpha=1)

# %%
y_pred_two = model_two.predict(scaled_X_test)

# %%
mean_squared_error(y_test,y_pred_two)
# Out:
# 2.3190215794287514

# %%
X_train, X_other, y_train, y_other = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
X_eval, X_test, y_eval, y_test = train_test_split(X_other, y_other, test_size=0.5, random_state=101)

# %%
X_train.shape
# Out:
# (140, 3)

# %%
X_eval.shape
# Out:
# (30, 3)

# %%
X_test.shape
# Out:
# (30, 3)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
X_train = scaler.transform(X_train)

# %%
X_eval = scaler.transform(X_eval)

# %%
X_test = scaler.transform(X_test)

# %%
from sklearn.linear_model import Ridge

# %%
model_one = Ridge(alpha = 100)

# %%
model_one.fit(X_train,y_train)
# Out:
# Ridge(alpha=100)

# %%
y_eval_pred = model_one.predict(X_eval)

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
mean_squared_error(y_eval,y_eval_pred)
# Out:
# 7.320101458823872

# %%
model_two = Ridge(alpha=1)

# %%
model_two.fit(X_train,y_train)
# Out:
# Ridge(alpha=1)

# %%
new_eval_pred = model_two.predict(X_eval)

# %%
mean_squared_error(y_eval,new_eval_pred)
# Out:
# 2.3837830750569866

# %%
y_final_test_pred = model_two.predict(X_test)

# %%
mean_squared_error(y_test,y_final_test_pred)
# Out:
# 2.254260083800517

# %%
X
# Out:
#         TV  radio  newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
X_train = scaler.transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
model = Ridge(alpha = 100)

# %%
from sklearn.model_selection import cross_val_score

# %%
score = cross_val_score(model, X_train,y_train,scoring = 'neg_mean_squared_error',cv=5)

# %%
score
# Out:
# array([ -9.32552967,  -4.9449624 , -11.39665242,  -7.0242106 ,
#         -8.38562723])

# %%
abs(score.mean())
# Out:
# 8.215396464543607

# %%
model2 = Ridge(alpha = 1)

# %%
score2 = cross_val_score(model2, X_train,y_train,scoring = 'neg_mean_squared_error',cv=5)

# %%
abs(score2.mean())
# Out:
# 3.344839296530695

# %%
model2.fit(X_train,y_train)
# Out:
# Ridge(alpha=1)

# %%
y_pred = model2.predict(X_test)

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 2.3190215794287514

# %%
from sklearn.model_selection import cross_validate

# %%
model = Ridge(alpha = 100)

# %%
scores = cross_validate(model, X_train,y_train,
                        scoring = ['neg_mean_absolute_error','neg_mean_squared_error'],cv =10)

# %%
scores = pd.DataFrame(scores)

# %%
scores
# Out:
#    fit_time  score_time  test_neg_mean_absolute_error  \
# 0  0.003708    0.001517                     -1.810212
# 1  0.001596    0.000000                     -2.541958
# 2  0.001553    0.001642                     -1.469594
# 3  0.001655    0.001518                     -1.862769
# 4  0.002017    0.001000                     -2.520697
# 5  0.002002    0.001996                     -2.459995
# 6  0.002205    0.002092                     -1.451971
# 7  0.002998    0.002063                     -2.377395
# 8  0.001742    0.002880                     -2.443344
# 9  0.002013    0.001988                     -1.899797
#
#    test_neg_mean_squared_error
# 0                    -6.060671
# 1                   -10.627031
# 2                    -3.993426
# 3                    -5.009494
# 4                    -9.141800
# 5                   -13.086256
# 6                    -3.839405
# 7                    -9.058786
# 8                    -9.055457
# 9                    -5.778882

# %%
scores.mean()
# Out:
# fit_time                        0.002149
# score_time                      0.001670
# test_neg_mean_absolute_error   -2.083773
# test_neg_mean_squared_error    -7.565121
# dtype: float64

# %%
model = Ridge(alpha = 1)

# %%
scores = cross_validate(model,X_train,y_train,
                        scoring=['neg_mean_absolute_error','neg_mean_squared_error'],cv=10)

# %%
scores = pd.DataFrame(scores)

# %%
scores.mean()
# Out:
# fit_time                        0.002917
# score_time                      0.002266
# test_neg_mean_absolute_error   -1.308467
# test_neg_mean_squared_error    -3.323018
# dtype: float64

# %%
model.fit(X_train,y_train)
# Out:
# Ridge(alpha=1)

# %%
y_pred = model.predict(X_test)

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 2.3190215794287514

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 1.2168768443580582

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {
    'alpha': [0.001, 0.01, 0.1, 1.0, 10.0],
    'l1_ratio': [0.1, 0.5, 0.7, 0.9, 1.0]
}

# %%
from sklearn.linear_model import ElasticNet

# %%
model = ElasticNet()

# %%
gridmodel = GridSearchCV(estimator = model,param_grid = param_grid,
                         scoring = 'neg_mean_squared_error',cv=5,verbose=1)

# %%
gridmodel.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# GridSearchCV(cv=5, estimator=ElasticNet(),
#              param_grid={'alpha': [0.001, 0.01, 0.1, 1.0, 10.0],
#                          'l1_ratio': [0.1, 0.5, 0.7, 0.9, 1.0]},
#              scoring='neg_mean_squared_error', verbose=1)

# %%
gridmodel.best_estimator_
# Out:
# ElasticNet(alpha=0.1, l1_ratio=1.0)

# %%
results = pd.DataFrame(gridmodel.cv_results_)

# %%
results
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_alpha  \
# 0        0.006497      0.007153         0.001897        0.000765        0.001
# 1        0.002936      0.000629         0.001210        0.000436        0.001
# 2        0.002227      0.000687         0.001411        0.000505        0.001
# 3        0.002234      0.000280         0.001032        0.000041        0.001
# 4        0.002427      0.000469         0.001283        0.000347        0.001
# 5        0.001852      0.000436         0.000610        0.000498        0.010
# 6        0.001125      0.000242         0.000396        0.000485        0.010
# 7        0.001317      0.000406         0.000626        0.000513        0.010
# 8        0.001402      0.000497         0.000302        0.000401        0.010
# 9        0.001307      0.000406         0.000399        0.000489        0.010
# 10       0.001206      0.000403         0.000935        0.000224        0.100
# 11       0.001519      0.000467         0.000604        0.000493        0.100
# 12       0.001206      0.000401         0.000617        0.000505        0.100
# 13       0.002189      0.001312         0.000800        0.000400        0.100
# 14       0.001442      0.000778         0.000891        0.000491        0.100
# 15       0.001567      0.000358         0.000306        0.000613        1.000
# 16       0.000729      0.000639         0.000817        0.000697        1.000
# 17       0.001227      0.000450         0.000509        0.000444        1.000
# 18       0.001281      0.000345         0.000400        0.000490        1.000
# 19       0.001620      0.000507         0.000528        0.000460        1.000
# 20       0.002150      0.000248         0.000420        0.000516       10.000
# 21       0.001925      0.000548         0.000580        0.000475       10.000
# 22       0.001608      0.000490         0.000702        0.000602       10.000
# 23       0.001056      0.000113         0.000301        0.000601       10.000
# 24       0.001184      0.000362         0.000501        0.000447       10.000
#
#     param_l1_ratio                             params  split0_test_score  \
# 0              0.1  {'alpha': 0.001, 'l1_ratio': 0.1}          -3.140774
# 1              0.5  {'alpha': 0.001, 'l1_ratio': 0.5}          -3.140248
# 2              0.7  {'alpha': 0.001, 'l1_ratio': 0.7}          -3.139987
# 3              0.9  {'alpha': 0.001, 'l1_ratio': 0.9}          -3.139727
# 4              1.0  {'alpha': 0.001, 'l1_ratio': 1.0}          -3.139597
# 5              0.1   {'alpha': 0.01, 'l1_ratio': 0.1}          -3.155670
# 6              0.5   {'alpha': 0.01, 'l1_ratio': 0.5}          -3.149523
# 7              0.7   {'alpha': 0.01, 'l1_ratio': 0.7}          -3.146593
# 8              0.9   {'alpha': 0.01, 'l1_ratio': 0.9}          -3.143761
# 9              1.0   {'alpha': 0.01, 'l1_ratio': 1.0}          -3.142382
# 10             0.1    {'alpha': 0.1, 'l1_ratio': 0.1}          -3.453021
# 11             0.5    {'alpha': 0.1, 'l1_ratio': 0.5}          -3.325440
# 12             0.7    {'alpha': 0.1, 'l1_ratio': 0.7}          -3.269880
# 13             0.9    {'alpha': 0.1, 'l1_ratio': 0.9}          -3.221397
# 14             1.0    {'alpha': 0.1, 'l1_ratio': 1.0}          -3.206943
# 15             0.1    {'alpha': 1.0, 'l1_ratio': 0.1}          -9.827475
# 16             0.5    {'alpha': 1.0, 'l1_ratio': 0.5}          -8.707071
# 17             0.7    {'alpha': 1.0, 'l1_ratio': 0.7}          -7.920870
# 18             0.9    {'alpha': 1.0, 'l1_ratio': 0.9}          -6.983855
# 19             1.0    {'alpha': 1.0, 'l1_ratio': 1.0}          -6.468807
# 20             0.1   {'alpha': 10.0, 'l1_ratio': 0.1}         -27.385346
# 21             0.5   {'alpha': 10.0, 'l1_ratio': 0.5}         -31.130307
# 22             0.7   {'alpha': 10.0, 'l1_ratio': 0.7}         -31.130307
# 23             0.9   {'alpha': 10.0, 'l1_ratio': 0.9}         -31.130307
# 24             1.0   {'alpha': 10.0, 'l1_ratio': 1.0}         -31.130307
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0           -1.617818          -5.376771          -2.239327
# 1           -1.618874          -5.375274          -2.240185
# 2           -1.619404          -5.374526          -2.240616
# 3           -1.619934          -5.373769          -2.241048
# 4           -1.620200          -5.373395          -2.241265
# 5           -1.578515          -5.404503          -2.215563
# 6           -1.587881          -5.388993          -2.222885
# 7           -1.592728          -5.381305          -2.226729
# 8           -1.597686          -5.373661          -2.230697
# 9           -1.600207          -5.369856          -2.232727
# 10          -1.405190          -5.789125          -2.187302
# 11          -1.427522          -5.595610          -2.163089
# 12          -1.442432          -5.502437          -2.163950
# 13          -1.465339          -5.416447          -2.173493
# 14          -1.480065          -5.376257          -2.182076
# 15          -5.261525         -11.875347          -7.449195
# 16          -4.214228         -10.879261          -6.204545
# 17          -3.549562         -10.024877          -5.379553
# 18          -2.790355          -8.997108          -4.414928
# 19          -2.391483          -8.410171          -3.893566
# 20         -19.159534         -27.635464         -24.154104
# 21         -22.549433         -31.155204         -27.963447
# 22         -22.549433         -31.155204         -27.963447
# 23         -22.549433         -31.155204         -27.963447
# 24         -22.549433         -31.155204         -27.963447
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0           -4.344027        -3.343743        1.369198               11
# 1           -4.342353        -3.343387        1.368120               10
# 2           -4.341578        -3.343222        1.367589                9
# 3           -4.340742        -3.343044        1.367047                8
# 4           -4.340324        -3.342956        1.366777                7
# 5           -4.366017        -3.344054        1.393985               12
# 6           -4.348948        -3.339646        1.383510                6
# 7           -4.340462        -3.337563        1.378228                5
# 8           -4.332009        -3.335563        1.372915                4
# 9           -4.327795        -3.334594        1.370248                3
# 10          -4.645576        -3.496043        1.591601               15
# 11          -4.451679        -3.392668        1.506827               14
# 12          -4.356738        -3.347088        1.462765               13
# 13          -4.263887        -3.308112        1.417693                2
# 14          -4.218460        -3.292760        1.394613                1
# 15          -8.542329        -8.591174        2.222939               20
# 16          -7.173031        -7.435627        2.255532               19
# 17          -6.324836        -6.639940        2.206213               18
# 18          -5.545769        -5.746403        2.128364               17
# 19          -5.105922        -5.253990        2.073832               16
# 20         -18.968161       -23.460522        3.794608               21
# 21         -21.698192       -26.899317        4.077240               22
# 22         -21.698192       -26.899317        4.077240               22
# 23         -21.698192       -26.899317        4.077240               22
# 24         -21.698192       -26.899317        4.077240               22
