# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv("C:\\Users\\User\\Downloads\\UNZIP_FOR_NOTEBOOKS_FINAL (1)\\DATA\\penguins_size.csv")

# %%
df.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
# 2  Adelie  Torgersen              40.3             18.0              195.0
# 3  Adelie  Torgersen               NaN              NaN                NaN
# 4  Adelie  Torgersen              36.7             19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %%
df.isnull().sum()
# Out:
# species               0
# island                0
# culmen_length_mm      2
# culmen_depth_mm       2
# flipper_length_mm     2
# body_mass_g           2
# sex                  10
# dtype: int64

# %%
df[df['culmen_length_mm'].isnull()]
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 3    Adelie  Torgersen               NaN              NaN                NaN
# 339  Gentoo     Biscoe               NaN              NaN                NaN
#
#      body_mass_g  sex
# 3            NaN  NaN
# 339          NaN  NaN

# %%
df = df.drop([3,339],axis = 0)

# %%
df.reset_index(inplace = True,drop = True)

# %%
df
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen              39.1             18.7              181.0
# 1    Adelie  Torgersen              39.5             17.4              186.0
# 2    Adelie  Torgersen              40.3             18.0              195.0
# 3    Adelie  Torgersen              36.7             19.3              193.0
# 4    Adelie  Torgersen              39.3             20.6              190.0
# ..      ...        ...               ...              ...                ...
# 337  Gentoo     Biscoe              47.2             13.7              214.0
# 338  Gentoo     Biscoe              46.8             14.3              215.0
# 339  Gentoo     Biscoe              50.4             15.7              222.0
# 340  Gentoo     Biscoe              45.2             14.8              212.0
# 341  Gentoo     Biscoe              49.9             16.1              213.0
#
#      body_mass_g     sex
# ...

# %%
df.dropna(inplace = True)

# %%
df.isnull().sum()
# Out:
# species              0
# island               0
# culmen_length_mm     0
# culmen_depth_mm      0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# dtype: int64

# %%
df['sex'].value_counts()
# Out:
# sex
# MALE      168
# FEMALE    165
# .           1
# Name: count, dtype: int64

# %%
df[df['species']=='Gentoo'].groupby('sex').describe().T
# Out:
# sex                           .       FEMALE         MALE
# culmen_length_mm  count     1.0    58.000000    61.000000
#                   mean     44.5    45.563793    49.473770
#                   std       NaN     2.051247     2.720594
#                   min      44.5    40.900000    44.400000
#                   25%      44.5    43.850000    48.100000
#                   50%      44.5    45.500000    49.500000
#                   75%      44.5    46.875000    50.500000
#                   max      44.5    50.500000    59.600000
# culmen_depth_mm   count     1.0    58.000000    61.000000
#                   mean     15.7    14.237931    15.718033
#                   std       NaN     0.540249     0.741060
#                   min      15.7    13.100000    14.100000
#                   25%      15.7    13.800000    15.200000
#                   50%      15.7    14.250000    15.700000
#                   75%      15.7    14.600000    16.100000
# ...

# %%
df.at[335,'sex']='FEMALE'

# %%
df['sex'].unique()
# Out:
# array(['MALE', 'FEMALE'], dtype=object)

# %%
sns.pairplot(hue='species',data = df)
plt.show()

# %%
X = pd.get_dummies(data = df.drop('species',axis=1),drop_first=True,dtype = int)
y = df['species']

# %%
X
# Out:
#      culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g  \
# 0                39.1             18.7              181.0       3750.0
# 1                39.5             17.4              186.0       3800.0
# 2                40.3             18.0              195.0       3250.0
# 3                36.7             19.3              193.0       3450.0
# 4                39.3             20.6              190.0       3650.0
# ..                ...              ...                ...          ...
# 337              47.2             13.7              214.0       4925.0
# 338              46.8             14.3              215.0       4850.0
# 339              50.4             15.7              222.0       5750.0
# 340              45.2             14.8              212.0       5200.0
# 341              49.9             16.1              213.0       5400.0
#
#      island_Dream  island_Torgersen  sex_MALE
# 0               0                 1         1
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model = DecisionTreeClassifier()

# %%
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
preds = model.predict(X_test)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,preds))
# Out:
#               precision    recall  f1-score   support
#
#       Adelie       0.95      0.98      0.96        41
#    Chinstrap       0.95      0.91      0.93        23
#       Gentoo       1.00      1.00      1.00        37
#
#     accuracy                           0.97       101
#    macro avg       0.97      0.96      0.97       101
# weighted avg       0.97      0.97      0.97       101

# %%
from sklearn.metrics import ConfusionMatrixDisplay

# %%
ConfusionMatrixDisplay.from_predictions(y_test,preds)
plt.show()

# %%
pd.DataFrame(data = model.feature_importances_, index = X.columns,columns = ['Feature Importances']).sort_values(by = 'Feature Importances',ascending=False)
# Out:
#                    Feature Importances
# flipper_length_mm             0.531201
# culmen_length_mm              0.346002
# island_Dream                  0.068185
# culmen_depth_mm               0.052214
# body_mass_g                   0.002398
# island_Torgersen              0.000000
# sex_MALE                      0.000000

# %%
from sklearn.tree import plot_tree

# %%
plt.figure(figsize = (12,8),dpi = 200)
plot_tree(model,feature_names =X.columns,filled = True)
plt.show()

# %%
df.shape
# Out:
# (334, 7)

# %%
model2 = DecisionTreeClassifier()

# %%
from sklearn.model_selection import GridSearchCV

# %%
paramgrid = {
    'criterion': ["gini", "entropy", "log_loss"],
    'splitter': ["best", "random"],
    'max_depth': [2, 3, 4, 5, 6, 7],
    'max_leaf_nodes': [3, 4, 5, 6, 7]
}

# %%
gridmodel = GridSearchCV(estimator = model2, param_grid =paramgrid,cv=5)

# %%
gridmodel.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy', 'log_loss'],
#                          'max_depth': [2, 3, 4, 5, 6, 7],
#                          'max_leaf_nodes': [3, 4, 5, 6, 7],
#                          'splitter': ['best', 'random']})

# %%
preds = gridmodel.predict(X_test)

# %%
print(classification_report(y_test,preds))
# Out:
#               precision    recall  f1-score   support
#
#       Adelie       0.97      0.95      0.96        41
#    Chinstrap       0.92      0.96      0.94        23
#       Gentoo       1.00      1.00      1.00        37
#
#     accuracy                           0.97       101
#    macro avg       0.96      0.97      0.97       101
# weighted avg       0.97      0.97      0.97       101

# %%
gridmodel.best_estimator_
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=5, max_leaf_nodes=7)

# %%
plt.figure(figsize = (12,8),dpi = 200)
plot_tree(gridmodel.best_estimator_,feature_names =X.columns,filled = True)
plt.show()
